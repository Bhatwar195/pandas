# %% [markdown]
# ## Pandas Day- 13

# %% [markdown]
# ## Join() function
# - **`join()`** in Pandas is used to combine two DataFrames based on their **index**.

# %%
import pandas as pd

# %% [markdown]
# ### Creating Sample DataFrames

# %%
df1 = pd.DataFrame({
    "Name": ["Amit", "Rahul", "Neha"],
    "Age": [21, 22, 20]
}, index=[0, 1, 2])

# %%
df1
# Out:
#     Name  Age
# 0   Amit   21
# 1  Rahul   22
# 2   Neha   20

# %%
df2
# Out:
#    C   D
# 0  4  40
# 1  5  50
# 2  6  60

# %%
df2 = pd.DataFrame({
    "Marks": [85, 78, 90]
}, index=[0, 1, 2])

df2
# Out:
#    Marks
# 0     85
# 1     78
# 2     90

# %% [markdown]
# ### Basic join() (Index-based)

# %%
df1.join(df2)
# Out:
#     Name  Age  Marks
# 0   Amit   21     85
# 1  Rahul   22     78
# 2   Neha   20     90

# %%
df2.join(df1)
# Out:
#    Marks   Name  Age
# 0     85   Amit   21
# 1     78  Rahul   22
# 2     90   Neha   20

# %% [markdown]
# ### Right Join

# %%
df1.join(df2,how='right')
# Out:
#    A   B  C   D
# 0  1  10  4  40
# 1  2  20  5  50

# %% [markdown]
# ### Left Join

# %%
df1.join(df2,how='left')
# Out:
#    A   B    C     D
# 0  1  10  4.0  40.0
# 1  2  20  5.0  50.0
# 2  3  30  NaN   NaN

# %% [markdown]
# ### Inner Join

# %%
df1.join(df2,how='inner')
# Out:
#    A   B  C   D
# 0  1  10  4  40
# 1  2  20  5  50

# %% [markdown]
# ### Outer Join

# %%
df1.join(df2,how='outer')
# Out:
#    A   B    C     D
# 0  1  10  4.0  40.0
# 1  2  20  5.0  50.0
# 2  3  30  NaN   NaN

# %%
df1 = pd.DataFrame({'A': [1,2,3],
 'B': [10,20,30]})
df2 = pd.DataFrame({'C': [4,5,6],
 'D': [40,50,60]})

# %%
df1.join(df2,lsuffix ='_1')
# Out:
#    A   B  C   D
# 0  1  10  4  40
# 1  2  20  5  50
# 2  3  30  6  60

# %%
df1.join(df2,lsuffix ='_2')
# Out:
#    A   B  C   D
# 0  1  10  4  40
# 1  2  20  5  50
# 2  3  30  6  60
